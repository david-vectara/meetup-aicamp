# %% [markdown]
# # Curate Tech Talks from Events
#
# We're now going to use the power of an LLM with a custom prompt to build our curated corpus.
#
# Here's some principals of how this is going to work:
#
# 1. We load our IDs of meetups stored in Parquet
# 2. For each ID:
#     1. We run a query against our event corpus with the metadata filter "doc.id = 'ID'", this limits the data to just that event
#     2. We use a custom prompt which:
#         * Looks at who was speaking, and what they were speaking about
#         * Identifies if this was a paid or free event
#         * Outputs the result into a JSON structure which we can leverage
#     3. With our JSON in hand, we can now create our curated corpus of tech talks with speaker information.

# %%
## Standard Imports and Logging

# %%
from vectara_client.core import Factory
from vectara_client.admin import CorpusBuilder
import pandas as pd
import duckdb
import pyarrow as pa
import logging
import json

logging.basicConfig(format='%(asctime)s:%(name)-35s %(levelname)s:%(message)s', level=logging.INFO, datefmt='%H:%M:%S %z')
logging.getLogger("OAuthUtil").setLevel(logging.WARNING)
logger = logging.getLogger(__name__)

# %%
client = Factory().build()
manager = client.corpus_manager
# Out:
# 14:52:40 +1000:Factory                             INFO:initializing builder
# 14:52:40 +1000:Factory                             INFO:Factory will load configuration from home directory
# 14:52:40 +1000:HomeConfigLoader                    INFO:Loading configuration from users home directory [C:\Users\david]
# 14:52:40 +1000:HomeConfigLoader                    INFO:Loading default configuration [default]
# 14:52:40 +1000:HomeConfigLoader                    INFO:Parsing config
# 14:52:40 +1000:root                                INFO:We are processing authentication type [OAuth2]
# 14:52:40 +1000:root                                INFO:initializing Client

# %%
con = duckdb.connect()
con.execute("CREATE TABLE session_events AS SELECT * FROM '../output/session_events.parquet';")

events = con.execute("SELECT * FROM session_events;").fetchdf().to_dict('records')

# Restore the JSON
for event in events:
    event['sessions'] = json.loads(event['sessions_json'])
    del event['sessions_json']

# %%
valid_sessions = []
events_by_id = {}

for event in events:
    events_by_id[event["id"]] = event
    if "sessions" in event:    
        sessions = event["sessions"]
        if "tech-sessions" in sessions:
            logger.debug(f"Event [{event['id']}] is valid")
            tech_sessions = sessions["tech-sessions"]
            if len(tech_sessions) == 0:
                logger.debug(f"tech-sessions is empty in event [{event['id']}]")
            else:
                for session_index, tech_session in enumerate(tech_sessions):
                    if "title" not in tech_session:
                        logger.debug(f"In event [{event['id']}], session [{session_index}], title is missing")
                        continue
                    if "description" not in tech_session:
                        logger.debug(f"In event [{event['id']}], session [{session_index}], description is missing")
                        continue
                    if "speakers" not in tech_session:
                        logger.debug(f"In event [{event['id']}], session [{session_index}], speakers is missing")
                        continue
                    else:
                        speakers = tech_session["speakers"]
                        if len(speakers) == 0:
                            logger.debug(f"In event [{event['id']}], session [{session_index}], speakers is empty")
                            tech_session["speakers_valid"] = False
                        else:
                            speakers_valid = True
                            for speaker_index, speaker in enumerate(speakers):
                                if "name" not in speaker:
                                    logger.debug(f"In event [{event['id']}], session [{session_index}], speaker [{speaker_index}] name is missing")
                                    speakers_valid = False
                                    break
                                if "bio" not in speaker:
                                    logger.debug(f"In event [{event['id']}], session [{session_index}], speaker [{speaker_index}] bio is missing")
                                    speakers_valid = False
                                    break
                                if "company" not in speaker:
                                    logger.debug(f"In event [{event['id']}], session [{session_index}], speaker [{speaker_index}] company is missing")
                                    speakers_valid = False
                                    break
                            if speakers_valid:
                                    logger.debug(f"In event [{event['id']}], session [{session_index}], speaker [{speaker_index}], Valid Speaker info")
                            tech_session["speakers_valid"] = speakers_valid

                    logger.debug(f"In event [{event['id']}], found valid session [{session_index}]")
                    tech_session["event_id"] = event["id"]
                    tech_session["session_index"] = session_index
                    valid_sessions.append(tech_session)
                    
        else:
            logger.debug(f"sessions in event [{event['id']}] is not valid, missing \"tech-sessions\"")
    else:
        logger.debug(f"event [{event['id']}] is not valid, missing \"sessions\"")

# %%
vectara_documents = []

for session in valid_sessions:
    event = events_by_id[session["event_id"]]

    description = session["description"]
    
    if session["speakers_valid"]:
        speakers = []
        companies = []
    
        # Semantic friendly represnetation
        speaker_infos = []
    
        for speaker_index, speaker in enumerate(session["speakers"]):
            name = speaker["name"]
            company = speaker["company"]
            bio = speaker["bio"]
            
            speakers.append(name)
            companies.append(company)
            speaker_infos.append(f"Speaker {speaker_index+1}: {name}@{company} - {bio}.")

        speaker_fragment = "\n".join(speaker_infos)
        description = f"Title:{event['title']}\nWhen: {event['event_date']}\n{description}\n{speaker_fragment}"
    
    metadata = {
        "event_date": event["event_date"],
        "event_year": event["event_year"],
        "event_month": event["event_month"],
        "event_type": event["event_type"],
        "is_online": event["is_online"],
        "url": event["url"],
        "speaker": speakers,
        "company": companies,
        "num_going": event["num_going"]
    }
    metadata_json = json.dumps(metadata)


    
    to_index = {
      "document_id": f"{event['id']}-{session['session_index']}",
      "title": session["title"],
      "metadata_json": metadata_json,
      "section": [
        {
          "text": description
        }
      ],
      "customDimension": [
          {"name": "going", "value": event["num_going"]}
      ]
    }
    vectara_documents.append(to_index)

# %%
for doc in vectara_documents[0:1]:
    logger.info(f"Tech session:\n{json.dumps(doc, indent=4)}")
# Out:
# 14:53:23 +1000:__main__                            INFO:Tech session:
# {
#     "document_id": "296597027-0",
#     "title": "In-person AI Meetup - GenAI, LLMs and Vector Search",
#     "metadata_json": "{\"event_date\": \"2023/10/17\", \"event_year\": \"2023\", \"event_month\": \"10\", \"event_type\": \"physical\", \"is_online\": false, \"url\": \"https://www.meetup.com/sydney-ai-tech-talks/events/296597027/\", \"speaker\": [\"Erick Ramirez\"], \"company\": [\"DataStax\"], \"num_going\": 49}",
#     "section": [
#         {
#             "text": "Title:In-person AI Meetup - GenAI, LLMs and Vector Search\nWhen: 2023/10/17\nThe event focused on AI-driven language processing with Vector Search. Participants learned how to perform vector searches on their data out-of-the-box with Cassandra. The event involved checkin, food/drink, networking, tech talks, and an open discussion.\nSpeaker 1: Erick Ramirez@DataStax - Erick Ramirez is a known figure in the field of AI-driven language processing and works with DataStax.."
#         }
#     ],
#     "customDimension": [
#         {
#             "name": "going",
#             "value": 49
#         }
#     ]
# }

# %%
from vectara_client.core import Factory
from vectara_client.admin import CorpusBuilder
from vectara_client.domain import Dimension
import logging

corpus = (CorpusBuilder("AICamp Sessions 2")
         .description("This is where we put our events with their raw description")
         .add_attribute("event_date", "When the event occurred in yyyy-mm-dd format", type="text")
         .add_attribute("event_year", "Which year the event occured")
         .add_attribute("event_month", "Which month the event occurred")
         .add_attribute("event_type", "Delivery format: (online or physical)")
         .add_attribute("is_online", "Whether this was an online event (boolean)", type="boolean")
         .add_attribute("url", "A trackback to meetups.com", indexed=False)
         .add_attribute("speaker", "List of presenters", type="text_list")
         .add_attribute("company", "List of organizations of the Speakers.", type="text_list")
         .add_attribute("num_going", "Count of people who are attending.", type="integer") 
        .build())

going_dim = Dimension("going", "How many attended", 0.2, 0.2)

corpus.customDimensions = [ going_dim ]

corpus_id = manager.create_corpus(corpus, delete_existing=True)
# Out:
# 14:53:27 +1000:CorpusManager                       INFO:Performing account checks before corpus creation for name [AICamp Sessions 2]
# 14:53:29 +1000:RequestUtil                         INFO:URL for operation list-corpora is: https://api.vectara.io/v1/list-corpora
# 14:53:30 +1000:CorpusManager                       INFO:Checking corpus with name [AICamp Sessions 2]
# 14:53:30 +1000:CorpusManager                       INFO:We found the following corpora with name [AICamp Sessions 2]: [749]
# 14:53:30 +1000:CorpusManager                       INFO:We found existing corpus with name [AICamp Sessions 2]
# 14:53:30 +1000:CorpusManager                       INFO:Deleting existing corpus named [AICamp Sessions 2]
# 14:53:30 +1000:RequestUtil                         INFO:URL for operation list-corpora is: https://api.vectara.io/v1/list-corpora
# 14:53:31 +1000:CorpusManager                       INFO:We found [1] potential matches
# 14:53:31 +1000:CorpusManager                       INFO:Deleting existing corpus with id [749]
# 14:53:31 +1000:RequestUtil                         INFO:URL for operation delete-corpus is: https://api.vectara.io/v1/delete-corpus
# 14:53:33 +1000:CorpusManager                       INFO:Account checks complete, creating the new corpus
# 14:53:33 +1000:RequestUtil                         INFO:URL for operation create-corpus is: https://api.vectara.io/v1/create-corpus
# 14:53:36 +1000:AdminService                        INFO:Created new corpus with 750

# %%
class SubIndexer:

    def __init__(self, indexer_service, corpus_id):
        self.logger = logging.getLogger(self.__class__.__name__)
        self.indexer_service = indexer_service
        self.corpus_id = corpus_id
        self.docs = []

    def add_doc(self, doc):
        self.docs.append(doc)

    def index_docs(self):
        try:
            for doc in self.docs:
                self.indexer_service.index_doc(self.corpus_id, doc)
        except Exception as e:
            # Ignore for lab
            self.logger("Error: {e}")

thread_count = 10
sub_indexers = [ SubIndexer(client.indexer_service, corpus_id) for x in range(thread_count)]


for index, doc in enumerate(vectara_documents):
    thread_index = index % thread_count
    sub_indexers[thread_index].add_doc(doc)

# %%
from threading import Thread

threads = []
for sub_indexer in sub_indexers:
    thread = Thread(target = sub_indexer.index_docs)
    threads.append(thread)
    thread.start()


for index, thread in enumerate(threads):
    logger.info(f"Joining thread {index}")
    thread.join()
# Out:
# 14:53:55 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:53:55 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:53:55 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:53:55 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:53:55 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:53:55 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:53:55 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:53:55 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:53:55 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:53:55 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:53:55 +1000:__main__                            INFO:Joining thread 0
# 14:53:58 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:53:58 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:53:59 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:53:59 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:53:59 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:53:59 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:53:59 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:53:59 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:53:59 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:53:59 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:00 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:01 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:02 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:02 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:02 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:02 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:02 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:02 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:02 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:02 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:02 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:03 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:05 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:06 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:06 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:06 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:06 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:06 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:06 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:06 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:06 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:06 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:08 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:09 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:09 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:09 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:09 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:09 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:09 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:09 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:09 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:10 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:10 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:11 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:13 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:13 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:13 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:13 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:13 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:13 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:13 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:13 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:13 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:13 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:16 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:16 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:16 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:16 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:16 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:16 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:17 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:17 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:17 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:17 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:18 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:18 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:19 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:19 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:19 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:19 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:19 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:19 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:20 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:20 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:21 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:21 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:22 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:22 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:23 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:23 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:23 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:23 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:23 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:23 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:23 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:23 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:25 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:26 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:26 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:26 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:26 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:26 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:27 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:27 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:27 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:27 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:28 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:28 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:29 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:29 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:29 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:29 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:29 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:29 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:29 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:29 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:31 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:31 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:32 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:33 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:34 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:34 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:34 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:34 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:34 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:34 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:34 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:34 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:34 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:36 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:37 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:37 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:37 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:37 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:37 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:37 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:37 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:37 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:37 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:38 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:41 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:41 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:41 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:41 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:41 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:41 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:41 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:41 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:42 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:42 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:43 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:44 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:44 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:44 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:44 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:45 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:45 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:45 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:45 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:45 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:45 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:47 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:47 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:47 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:47 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:48 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:48 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:48 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:48 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:48 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:48 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:49 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:49 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:50 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:50 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:50 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:51 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:52 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:52 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:52 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:52 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:52 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:52 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:52 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:53 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:53 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:54 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:55 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:55 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:55 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:55 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:55 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:55 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:56 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:56 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:56 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:57 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:57 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:58 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:58 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:58 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:58 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:59 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:59 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:59 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:59 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:54:59 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:00 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:02 +1000:__main__                            INFO:Joining thread 1
# 14:55:02 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:02 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:02 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:02 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:02 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:02 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:02 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:03 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:03 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:06 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:06 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:06 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:06 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:06 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:06 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:06 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:06 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:06 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:08 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:09 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:09 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:09 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:09 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:09 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:09 +1000:__main__                            INFO:Joining thread 2
# 14:55:09 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:09 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:09 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:12 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:12 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:12 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:12 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:13 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:13 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:13 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:15 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:15 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:15 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:18 +1000:RequestUtil                         INFO:URL for operation index is: https://api.vectara.io/v1/index
# 14:55:18 +1000:__main__                            INFO:Joining thread 3
# 14:55:18 +1000:__main__                            INFO:Joining thread 4
# 14:55:20 +1000:__main__                            INFO:Joining thread 5
# 14:55:20 +1000:__main__                            INFO:Joining thread 6
# 14:55:20 +1000:__main__                            INFO:Joining thread 7
# 14:55:20 +1000:__main__                            INFO:Joining thread 8
# 14:55:20 +1000:__main__                            INFO:Joining thread 9
